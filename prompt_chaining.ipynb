# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph , START , END
from typing import TypedDict

# %%
model = ChatOpenAI(model='gpt-5-nano')

# %%
class ChainState(TypedDict):
    title : str
    outline : str 
    blog : str

# %%
def create_outline(state:ChainState) -> ChainState:
    title =state['title']
    prompt=f"Create an outline for the blog post on this title - {title}"
    state['outline']=model.invoke(prompt).content
    return state 

def create_blog(state:ChainState) -> ChainState:
    outline=state['outline']
    title=state['title']
    prompt=f"Write an blog on this title - {title} here is its outline - {outline}"
    state['blog']=model.invoke(prompt).content
    return state

# %%
graph = StateGraph(ChainState)

graph.add_node("create_outline",create_outline)
graph.add_edge(START,"create_outline")
graph.add_node("create_blog",create_blog)
graph.add_edge("create_outline","create_blog")
graph.add_edge("create_blog",END)

workflow=graph.compile()

# %%
output=workflow.invoke({"title":"Technical vs Fundamental Analysis in Stock Market"})
print(output)
# Out:
# {'title': 'Technical vs Fundamental Analysis in Stock Market', 'outline': 'Here’s a clear, structured outline you can use to write a blog post titled “Technical vs Fundamental Analysis in Stock Market.”\n\n1) Introduction\n- Hook: why understanding both approaches matters for traders and investors\n- Define the two analyses at a high level\n- What readers will gain from the post\n- Brief note on the goal: clarity on when to use each method (and how they can complement each other)\n\n2) What is Technical Analysis?\n- Core premise: price reflects all known information; patterns and trends matter\n- Key concepts\n  - Price action, trends, support and resistance\n  - Chart patterns (e.g., triangles, head-and-shoulders)\n  - Timeframes and multiple chart perspectives\n- Common tools and indicators\n  - Moving averages, RSI, MACD, Bollinger Bands\n  - Volume analysis and momentum\n  - Candlestick patterns and chart formations\n- How signals are interpreted\n  - Entry/exit signals, risk management, stop-loss placement\n- When it’s most useful\n  - Short- to medium-term trading, rapid decision-making, liquidity-focused strategies\n- Limitations and pitfalls\n  - Data-snooping, false signals, overfitting, market regime changes\n\n3) What is Fundamental Analysis?\n- Core premise: determine intrinsic value through company and macro factors\n- Key components\n  - Financial statements: revenue, earnings, margins, cash flow\n  - Valuation measures: P/E, P/B, EV/EBITDA, dividend yield\n  - Growth drivers: revenue growth, margins, competitive advantage\n  - Qualitative factors: business model, management, industry structure, regulatory environment\n  - Macro factors: interest rates, inflation, economic cycles\n- How intrinsic value guides decisions\n  - Long-term investing, buy-and-hold, margin of safety\n- When it’s most useful\n  - Long horizons, capital allocation, stock selection based on fundamentals\n- Limitations and pitfalls\n  - Accounting quirks, optimistic/pessimistic forecasts, reliance on projections\n\n4) Side-by-Side Comparison\n- Data sources and time horizons\n- What each analyzes: price action vs financial health and value\n- Typical outcomes: quick trades vs long-term positions\n- Risk and uncertainty profiles\n- Common assumptions and biases\n\n5) Strengths, Weaknesses, and Temporal Fit\n- Technical Analysis: strengths (timing, liquidity, trend-following), weaknesses (false signals, overtrading)\n- Fundamental Analysis: strengths (valuation discipline, long-term viability), weaknesses (estimation risk, slower to adapt)\n- Ideal use cases for each approach\n- Market conditions that favor one over the other (e.g., high volatility vs steady growth)\n\n6) How to Use Them Together (Hybrid Approach)\n- Rationale for combining both analyses\n- Suggested workflow\n  - Step 1: perform fundamental assessment to identify undervalued/overvalued opportunities\n  - Step 2: use technical analysis to time entries/exits\n  - Step 3: apply risk controls and position sizing\n  - Step 4: monitor for regime shifts and adjust\n- Practical examples of integration\n  - Example: a fundamentally strong stock showing a favorable chart setup\n  - Example: a technically bearish signal on a stock with improving fundamentals (risk management)\n- Common pitfalls in blending methods and how to avoid them\n\n7) Practical Guides and Checklists\n- Fundamental analysis checklist\n  - Key financial metrics to review\n  - Qualitative risk factors to assess\n  - Valuation sanity checks\n- Technical analysis checklist\n  - Timeframe selection, trend confirmation, indicators to use, risk controls\n- Decision flow you can follow before taking a position\n\n8) Case Studies (Illustrative)\n- Case Study A: Strong fundamentals but neutral/negative technical signals (what to do)\n- Case Study B: Positive technicals but weak fundamentals (risk considerations)\n- Case Study C: Both analyses align (higher confidence scenario)\n- Lessons learned from each scenario\n\n9) Too ...

# %%
print(output["outline"])
# Out:
# Here’s a clear, structured outline you can use to write a blog post titled “Technical vs Fundamental Analysis in Stock Market.”
#
# 1) Introduction
# - Hook: why understanding both approaches matters for traders and investors
# - Define the two analyses at a high level
# - What readers will gain from the post
# - Brief note on the goal: clarity on when to use each method (and how they can complement each other)
#
# 2) What is Technical Analysis?
# - Core premise: price reflects all known information; patterns and trends matter
# - Key concepts
#   - Price action, trends, support and resistance
#   - Chart patterns (e.g., triangles, head-and-shoulders)
#   - Timeframes and multiple chart perspectives
# - Common tools and indicators
#   - Moving averages, RSI, MACD, Bollinger Bands
#   - Volume analysis and momentum
#   - Candlestick patterns and chart formations
# - How signals are interpreted
#   - Entry/exit signals, risk management, stop-loss placement
# - When it’s most useful
#   - Short- to medium-term trading, rapid decision-making, liquidity-focused strategies
# - Limitations and pitfalls
#   - Data-snooping, false signals, overfitting, market regime changes
#
# 3) What is Fundamental Analysis?
# - Core premise: determine intrinsic value through company and macro factors
# - Key components
#   - Financial statements: revenue, earnings, margins, cash flow
#   - Valuation measures: P/E, P/B, EV/EBITDA, dividend yield
#   - Growth drivers: revenue growth, margins, competitive advantage
#   - Qualitative factors: business model, management, industry structure, regulatory environment
#   - Macro factors: interest rates, inflation, economic cycles
# - How intrinsic value guides decisions
#   - Long-term investing, buy-and-hold, margin of safety
# - When it’s most useful
#   - Long horizons, capital allocation, stock selection based on fundamentals
# - Limitations and pitfalls
#   - Accounting quirks, optimistic/pessimistic forecasts, reliance on projections
#
# 4) Side-by-Side Comparison
# - Data sources and time horizons
# - What each analyzes: price action vs financial health and value
# - Typical outcomes: quick trades vs long-term positions
# - Risk and uncertainty profiles
# - Common assumptions and biases
#
# 5) Strengths, Weaknesses, and Temporal Fit
# - Technical Analysis: strengths (timing, liquidity, trend-following), weaknesses (false signals, overtrading)
# - Fundamental Analysis: strengths (valuation discipline, long-term viability), weaknesses (estimation risk, slower to adapt)
# - Ideal use cases for each approach
# - Market conditions that favor one over the other (e.g., high volatility vs steady growth)
#
# 6) How to Use Them Together (Hybrid Approach)
# - Rationale for combining both analyses
# - Suggested workflow
#   - Step 1: perform fundamental assessment to identify undervalued/overvalued opportunities
#   - Step 2: use technical analysis to time entries/exits
#   - Step 3: apply risk controls and position sizing
#   - Step 4: monitor for regime shifts and adjust
# - Practical examples of integration
#   - Example: a fundamentally strong stock showing a favorable chart setup
#   - Example: a technically bearish signal on a stock with improving fundamentals (risk management)
# - Common pitfalls in blending methods and how to avoid them
#
# 7) Practical Guides and Checklists
# - Fundamental analysis checklist
#   - Key financial metrics to review
#   - Qualitative risk factors to assess
#   - Valuation sanity checks
# - Technical analysis checklist
#   - Timeframe selection, trend confirmation, indicators to use, risk controls
# - Decision flow you can follow before taking a position
#
# 8) Case Studies (Illustrative)
# - Case Study A: Strong fundamentals but neutral/negative technical signals (what to do)
# - Case Study B: Positive technicals but weak fundamentals (risk considerations)
# - Case Study C: Both analyses align (higher confidence scenario)
# - Lessons learned from each scenario
#
# 9) Tools, Resources, and Further Reading
# - Popular data sources for fundamentals (financial statements, earnings calls)
# - Charting and technical analysis tools
# - Books, courses, and reputable blogs for deeper learning
# - How to practice responsibly (paper trading, backtesting with bias awareness)
#
# 10) Conclusion
# - Recap of the core differences and complementarities
# - Actionable takeaway: start with a framework, not a single method
# - Encouragement to tailor the approach to your goals, risk tolerance, and time horizon
#
# Optional additions you can include if desired
# - FAQ section addressing common questions (e.g., “Is fundamental analysis enough for stock picking?”)
# - Glossary of key terms
# - Visuals suggestions (charts showing examples of technical signals and fundamental valuation metrics)

# %%
print(output["blog"])
# Out:
# Technical vs Fundamental Analysis in Stock Market
#
# Introduction
# - Hook: Understanding both technical and fundamental analysis is like having two different lenses to view the market. One helps you read the price action of today, the other helps you judge the value of tomorrow.
# - Define the two analyses at a high level: Technical analysis focuses on price, charts, and market behavior to time entries and exits; fundamental analysis focuses on a company’s intrinsic value based on financial health, growth prospects, and macro conditions.
# - What readers will gain: a clear framework for choosing when to use each method, how they complement each other, and practical steps to combine them in your trading or investing routine.
# - Brief goal: clarity on how to apply each method, and how to blend them to improve decision-making and risk management.
#
# What is Technical Analysis?
# - Core premise: price reflects all known information; patterns and trends matter.
# - Key concepts
#   - Price action, trends, support and resistance: identifying bullish/bearish directions and levels where price tends to pause or reverse.
#   - Chart patterns: triangles, head-and-shoulders, double tops/bottoms, flags, and other formations that suggest potential breakouts or continuations.
#   - Timeframes and multiple chart perspectives: analyzing charts across minutes, hours, days, and weeks to confirm signals.
# - Common tools and indicators
#   - Moving averages (e.g., 50-day, 200-day), RSI, MACD, Bollinger Bands
#   - Volume analysis and momentum: spikes in volume often accompany breakouts or reversals
#   - Candlestick patterns and chart formations: engulfing candles, doji, hammer, shooting star, etc.
# - How signals are interpreted
#   - Entry/exit signals, risk management, stop-loss placement
#   - Use of support/resistance, trend lines, and confirmation from multiple indicators
# - When it’s most useful
#   - Short- to medium-term trading, rapid decision-making, liquidity-focused strategies
# - Limitations and pitfalls
#   - Data-snooping, false signals, overfitting, market regime changes, reliance on historical patterns that may fail in new conditions
#
# What is Fundamental Analysis?
# - Core premise: determine intrinsic value through company and macro factors.
# - Key components
#   - Financial statements: revenue, earnings, margins, cash flow
#   - Valuation measures: price-to-earnings (P/E), price-to-book (P/B), EV/EBITDA, dividend yield
#   - Growth drivers: revenue growth, operating margins, competitive advantage, scalability
#   - Qualitative factors: business model, management quality, competitive landscape, regulatory environment
#   - Macro factors: interest rates, inflation, economic cycles, global growth
# - How intrinsic value guides decisions
#   - Long-term investing, buy-and-hold strategies, margin of safety
# - When it’s most useful
#   - Long horizons, capital allocation decisions, stock selection based on fundamentals
# - Limitations and pitfalls
#   - Accounting quirks, optimistic/pessimistic forecasts, reliance on projections, earnings management risks
#
# Side-by-Side Comparison
# - Data sources and time horizons
#   - Technical: price data, volume, derived indicators; focuses on near-term to intermediate trends
#   - Fundamental: financial statements, market data, qualitative assessments; focuses on long-term value
# - What each analyzes
#   - Technical: price action, patterns, momentum, liquidity
#   - Fundamental: financial health, valuation, competitive advantage, macro context
# - Typical outcomes
#   - Technical: quicker trades, momentum-driven moves, shorter holding periods
#   - Fundamental: longer-term positions, capital allocation, patient waiting for value realization
# - Risk and uncertainty profiles
#   - Technical: sensitive to market noise and regime shifts; can suffer from false signals
#   - Fundamental: subject to estimation risk and changes in assumptions; slower to react to price moves
# - Common assumptions and biases
#   - Technical: market efficiency gaps, pattern confirmation bias
#   - Fundamental: optimistic/pessimistic projections, survivorship and selection biases
#
# Strengths, Weaknesses, and Temporal Fit
# - Technical Analysis
#   - Strengths: timing capability, leveraging price momentum, useful in highly liquid markets
#   - Weaknesses: false signals, overtrading, can miss fundamental turns
#   - Ideal use cases: short- to medium-term trading, fast decision-making, liquidity-driven strategies
#   - Market conditions that favor it: high volatility, clear price patterns, liquid names
# - Fundamental Analysis
#   - Strengths: valuation discipline, focus on long-term viability, helps avoid overpaying
#   - Weaknesses: estimation risk, slower to adapt to rapid price changes, requires access to quality data
#   - Ideal use cases: long-term investing, stock selection with durable competitive advantages, capital allocation decisions
#   - Market conditions that favor it: steady or growing fundamental environments, clear earnings visibility
# - Temporal fit summary: technical often complements fundamental by providing timing and risk controls; fundamentals help you avoid value traps and identify viable long-term ideas.
#
# How to Use Them Together (Hybrid Approach)
# - Rationale for combining both analyses: technicals can optimize entry/exit timing for fundamentally sound ideas, while fundamentals guard against value traps in the long run.
# - Suggested workflow
#   - Step 1: perform fundamental assessment to identify undervalued/overvalued opportunities with durable prospects
#   - Step 2: use technical analysis to time entries and exits, confirm momentum, and manage risk
#   - Step 3: apply risk controls and position sizing to balance return and downside risk
#   - Step 4: monitor for regime shifts (e.g., changes in macro conditions or company fundamentals) and adjust
# - Practical examples of integration
#   - Example: a fundamentally strong stock shows a favorable chart setup (breakout on high volume) – consider a position with a defined stop and target
#   - Example: a stock with improving fundamentals but a technically bearish signal – assess risk tolerance, possibly wait for a clearer setup or use tighter risk controls
# - Common pitfalls in blending methods and how to avoid them
#   - Overreliance on one method; ensure both analyses inform your decision
#   - Inconsistent time horizons; align your approach with your goals (trading vs investing)
#   - Ignoring regime shifts; stay attuned to macro and sector changes
#
# Practical Guides and Checklists
# - Fundamental analysis checklist
#   - Key financial metrics: revenue growth, profitability (margins), cash flow, debt levels
#   - Valuation sanity checks: compare to peers, assess if price reflects growth prospects
#   - Qualitative risk factors: management quality, competitive moat, regulatory risks, product lifecycle
#   - Valuation sanity: discount future cash flows conservatively, consider multiple scenarios
# - Technical analysis checklist
#   - Timeframe selection: align with your horizon (intraday, swing, or position trading)
#   - Trend confirmation: higher highs/lows, trend-line breaks
#   - Indicators and signals: moving averages for trend, RSI/MACD for momentum, volume confirmation
#   - Risk controls: stop-loss placement, position sizing, risk-reward ratio target
# - Decision flow you can follow before taking a position
#   - Step-by-step: fundamental fit? yes/no → technical setup? yes/no → risk controls in place? yes → enter
#
# Case Studies (Illustrative)
# - Case Study A: Strong fundamentals but neutral/negative technical signals
#   - What to do: evaluate whether the long-term thesis remains intact; consider waiting for a technical confirmation or reducing exposure until a setup appears
#   - Lesson: fundamentals may point to value but mispricing can persist; price action can delay realization
# - Case Study B: Positive technicals but weak fundamentals
#   - What to do: assess downside risk; ensure risk controls and consider-position sizing; avoid assuming a quick rebound without a systemic improvement
#   - Lesson: price momentum can carry prices beyond intrinsic value; be prepared for fundamental disappointments
# - Case Study C: Both analyses align
#   - What to do: higher confidence; allocate with a well-defined risk-reward plan and monitor for regime changes
#   - Lesson: aligned signals increase conviction and reduce overall risk
#
# Tools, Resources, and Further Reading
# - Popular data sources for fundamentals
#   - Company financial statements (income statement, balance sheet, cash flow)
#   - Earnings calls and management guidance
#   - Industry reports and macro data (economic indicators, central bank commentary)
# - Charting and technical analysis tools
#   - Charting platforms with indicators and backtesting capabilities
#   - Community resources, price action libraries, and pattern recognition guides
# - Books, courses, and reputable blogs
#   - Foundational texts on both technical and fundamental analysis
#   - Courses that emphasize practical application, risk management, and portfolio integration
# - How to practice responsibly
#   - Paper trading to test ideas
#   - Backtesting with bias awareness; avoid overfitting to past data
#   - Start with a clear thesis and document assumptions and risk controls
#
# Conclusion
# - Recap: Technical analysis excels at timing and momentum; fundamental analysis anchors your decisions in real value and long-term viability. Used together, they form a more robust framework than either approach alone.
# - Actionable takeaway: start with a framework, not a single method. Build your workflow around a fundamental thesis, then apply technical signals to time trades and manage risk.
# - Final thought: tailor the approach to your goals, risk tolerance, and time horizon. Practice, review, and adapt as market conditions evolve.
#
# Optional additions you can include
# - FAQ section addressing common questions (e.g., “Is fundamental analysis enough for stock picking?”)
# - Glossary of key terms
# - Visuals suggestions: consider adding charts that illustrate technical signals (trend lines, RSI overbought/oversold) and fundamental valuation metrics (P/E, EV/EBITDA, growth rates) to enhance understanding
#
# If you’d like, I can tailor this post to a specific audience (new investors, experienced traders, a particular market like equities or ETFs) or provide a version with embedded visuals and example charts.
